# %% [markdown]
# <a href="https://colab.research.google.com/github/tariqhamad/Email-subject-generator-/blob/main/email_subject_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from openai import OpenAI
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')
openai = OpenAI(api_key=api_key)

# %%
system_prompt = 'You are an email expert that helps in subject lines'
user_prompt = 'Hi ed, kindly find the attached document as discussed'

# %%
messages = [{"role":"system","content":system_prompt},
            {"role":"user", "content":user_prompt}]

# %%
response = openai.chat.completions.create(model='gpt-4.1-nano', messages=messages)

# %%
response.choices[0].message.content
# Out:
# 'Certainly! Here are some professional and clear subject line options for your email:\n\n1. Document Attached as Discussed  \n2. Requested Document Enclosed  \n3. Follow-Up: Attached Document  \n4. As Discussed – Document for Your Review  \n5. Attached: Document for Your Reference  \n\nWould you like the subject line to be more formal, casual, or include any specific details?'
